# %%
# !pip install tensorflow
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.2.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow) (78.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow) (4.13.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy<2.2.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 4.2 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 3.0 MB/s eta 0:00:00:00:0100:02
# Downloading absl_py-2.2.1-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.3/277.3 kB 10.7 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.1 MB/s eta 0:00:00
# Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 11.6 MB/s eta 0:00:0000:0100:01
# Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.9.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 11.0 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 11.6 MB/s eta 0:00:0000:0100:01
# Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.7 MB/s eta 0:00:00
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 10.5 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 11.7 MB/s eta 0:00:0000:0100:01
# Downloading termcolor-3.0.0-py3-none-any.whl (6.3 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 8.4 MB/s eta 0:00:00
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 8.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 11.3 MB/s eta 0:00:0000:0100:01
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 10.0 MB/s eta 0:00:00
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (403 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.6/403.6 kB 10.4 MB/s eta 0:00:0000:01
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 10.6 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.9 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, werkzeug, urllib3, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, markdown, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, absl-py, tensorboard, requests, ml-dtypes, markdown-it-py, h5py, astunparse, rich, keras, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed absl-py-2.2.1 astunparse-1.6.3 certifi-2025.1.31 charset-normalizer-3.4.1 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 idna-3.10 keras-3.9.1 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.8 numpy-2.1.3 opt-einsum-3.4.0 optree-0.14.1 protobuf-5.29.4 requests-2.32.3 rich-14.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 termcolor-3.0.0 urllib3-2.3.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2
# Requirement already satisfied: gym in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from gym) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from gym) (0.0.8)
# Requirement already satisfied: keras in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: absl-py in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (2.2.1)
# Requirement already satisfied: numpy in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (2.1.3)
# Requirement already satisfied: rich in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from optree->keras) (4.13.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting keras-rl2
#   Downloading keras_rl2-1.0.5-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: tensorflow in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras-rl2) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (2.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (3.4.0)
# Requirement already satisfied: packaging in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (2.32.3)
# Requirement already satisfied: setuptools in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (78.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (3.9.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorflow->keras-rl2) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->keras-rl2) (0.45.1)
# Requirement already satisfied: rich in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->keras-rl2) (14.0.0)
# Requirement already satisfied: namex in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->keras-rl2) (0.0.8)
# Requirement already satisfied: optree in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->keras-rl2) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->keras-rl2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->keras-rl2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->keras-rl2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->keras-rl2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->keras-rl2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->keras-rl2) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/nimai/Desktop/MyPrograms/Courses/Mini-Project/cage-challenge-2/myenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->keras-rl2) (0.1.2)
# Downloading keras_rl2-1.0.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.5

# %%
from CybORG import CybORG
import inspect
from CybORG.Agents import B_lineAgent
from CybORG.Agents.Wrappers.ChallengeWrapper import ChallengeWrapper
import random

# %%
MAX_STEPS_PER_GAME = 30
MAX_EPS = 100

# %%
print("Setup")
path = str(inspect.getfile(CybORG))
path = path[:-10] + f'/Shared/Scenarios/Scenario2.yaml'

agent_name = 'Blue'
# wrappers = FixedFlatWrapper(EnumActionWrapper(CybORG(path, 'sim', agents={'Red': B_lineAgent})))
# cyborg = OpenAIGymWrapper(env=wrappers,agent_name=agent_name)

env = ChallengeWrapper(env=CybORG(path, 'sim', agents={'Red': B_lineAgent}), agent_name=agent_name)
# Out:
# Setup

# %%
states = env.observation_space.shape[0]
actions = env.action_space.n

print(f"States: {states}")
print(f"Actions: {actions}")
# Out:
# States: 52
# Actions: 145

# %%
episodes = 15
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    for j in range(MAX_STEPS_PER_GAME):
        action = random.randint(0, actions-1)
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-80.10000000000001
# Episode:2 Score:-225.69999999999993
# Episode:3 Score:-214.79999999999993
# Episode:4 Score:-136.79999999999995
# Episode:5 Score:-137.7
# Episode:6 Score:-227.69999999999993
# Episode:7 Score:-48.600000000000016
# Episode:8 Score:-138.79999999999998
# Episode:9 Score:-224.79999999999993
# Episode:10 Score:-224.99999999999997
# Episode:11 Score:-224.79999999999993
# Episode:12 Score:-228.79999999999993
# Episode:13 Score:-225.79999999999993
# Episode:14 Score:-204.79999999999995
# Episode:15 Score:-223.69999999999993

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import torch.nn.functional as F

# %%
class DuelingDQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DuelingDQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        
        # Value stream
        self.value_fc = nn.Linear(128, 64)
        self.value = nn.Linear(64, 1)
        
        # Advantage stream
        self.advantage_fc = nn.Linear(128, 64)
        self.advantage = nn.Linear(64, action_dim)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        
        value = F.relu(self.value_fc(x))
        value = self.value(value)
        
        advantage = F.relu(self.advantage_fc(x))
        advantage = self.advantage(advantage)
        
        # Combine value and advantage streams
        q_vals = value + (advantage - advantage.mean(dim=1, keepdim=True))
        return q_vals

# Replay Memory to store transitions
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
# Hyperparameters
BATCH_SIZE = 64
GAMMA = 0.99
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_DECAY = 0.995
LR = 0.001
TARGET_UPDATE = 10
MAX_EPISODES = 2000
MAX_STEPS_PER_GAME = 100  # or as defined in your environment
MEMORY_SIZE = 10000

# %%
memory = ReplayMemory(MEMORY_SIZE)
policy_net = DuelingDQN(states, actions)
target_net = DuelingDQN(states, actions)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LR)
criterion = nn.MSELoss()

epsilon = EPSILON_START

# %%
avg_score = 0
for episode in range(1, MAX_EPISODES + 1):
    state = env.reset()
    state = np.array(state)
    score = 0
    done = False
    
    for step in range(MAX_STEPS_PER_GAME):
        # Epsilon-greedy action selection
        if random.random() < epsilon:
            action = random.randrange(actions)
        else:
            with torch.no_grad():
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                q_values = policy_net(state_tensor)
                action = torch.argmax(q_values).item()
        
        next_state, reward, done, _ = env.step(action)
        next_state = np.array(next_state)
        memory.push(state, action, reward, next_state, done)
        state = next_state
        score += reward
        
        if done:
            break
        
        # Training step: update policy network if enough samples in replay memory
        if len(memory) >= BATCH_SIZE:
            transitions = memory.sample(BATCH_SIZE)
            batch_state, batch_action, batch_reward, batch_next_state, batch_done = zip(*transitions)
            
            batch_state = torch.FloatTensor(batch_state)
            batch_action = torch.LongTensor(batch_action).unsqueeze(1)
            batch_reward = torch.FloatTensor(batch_reward).unsqueeze(1)
            batch_next_state = torch.FloatTensor(batch_next_state)
            batch_done = torch.FloatTensor(batch_done).unsqueeze(1)
            
            # Compute current Q values from policy network
            current_q = policy_net(batch_state).gather(1, batch_action)
            
            # Compute target Q values using target network
            next_q = target_net(batch_next_state).max(1)[0].unsqueeze(1)
            expected_q = batch_reward + GAMMA * next_q * (1 - batch_done)
            
            # Compute loss and perform backpropagation
            loss = criterion(current_q, expected_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    
    avg_score += score
    
    # Decay epsilon
    epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
    if episode % 50 == 0:
        avg_score /= 50
        print(f"Episode: {episode} Avg Score: {avg_score:.2f}")
        avg_score = 0
    
    # Update target network periodically
    if episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
# Out:
# Episode: 50 Avg Score: -452.53
# Episode: 100 Avg Score: -405.02
# Episode: 150 Avg Score: -469.58
# Episode: 200 Avg Score: -568.61
# Episode: 250 Avg Score: -627.64
# Episode: 300 Avg Score: -512.07
# Episode: 350 Avg Score: -466.87
# Episode: 400 Avg Score: -323.49
# Episode: 450 Avg Score: -247.32
# Episode: 500 Avg Score: -187.26
# Episode: 550 Avg Score: -297.40
# Episode: 600 Avg Score: -145.98
# Episode: 650 Avg Score: -160.36
# Episode: 700 Avg Score: -197.49
# Episode: 750 Avg Score: -115.92
# Episode: 800 Avg Score: -131.02
# Episode: 850 Avg Score: -80.50
# Episode: 900 Avg Score: -81.49
# Episode: 950 Avg Score: -70.12
# Episode: 1000 Avg Score: -73.70
# Episode: 1050 Avg Score: -58.19
# Episode: 1100 Avg Score: -63.99
# Episode: 1150 Avg Score: -75.05
# Episode: 1200 Avg Score: -133.21
# Episode: 1250 Avg Score: -79.19
# Episode: 1300 Avg Score: -60.96
# Episode: 1350 Avg Score: -48.17
# Episode: 1400 Avg Score: -70.49
# Episode: 1450 Avg Score: -78.58
# Episode: 1500 Avg Score: -75.53
# Episode: 1550 Avg Score: -68.82
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 35
#      33 batch_action = torch.LongTensor(batch_action).unsqueeze(1)
#      34 batch_reward = torch.FloatTensor(batch_reward).unsqueeze(1)
# ---> 35 batch_next_state = torch.FloatTensor(batch_next_state)
#      36 batch_done = torch.FloatTensor(batch_done).unsqueeze(1)
#      38 # Compute current Q values from policy network
#
# KeyboardInterrupt:
